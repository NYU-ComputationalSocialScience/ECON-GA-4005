# %% [markdown]
# # Linear Models II,  GLM
#
# **Prerequisites**
#
# - Linear Algebra
# - Calculus
# - Some probability/statistics
# - Linear Models 1
#
#
# **Outcomes**
#
# - Understand the generalized linear model (GLM)
# - Apply GLM to binary, count, and severity targets

# %%
# %pip install --user pyarrow python-snappy
# Out:
# Collecting pyarrow
#   Downloading https://files.pythonhosted.org/packages/12/e4/40ea3e2a2d71ef1503c1cae1534d50a3534120e49446a800aca7075f2fe7/pyarrow-7.0.0.tar.gz (816kB)
#      |████████████████████████████████| 819kB 10.1MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting python-snappy
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/python-snappy/
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/9f/2f/314ebc4ad5faeab6b3d485be443d1493636026afe72a52400342d7f76003/python-snappy-0.6.0.tar.gz
#   Downloading https://files.pythonhosted.org/packages/9f/2f/314ebc4ad5faeab6b3d485be443d1493636026afe72a52400342d7f76003/python-snappy-0.6.0.tar.gz
# Collecting numpy>=1.16.6 (from pyarrow)
#   Downloading https://files.pythonhosted.org/packages/0a/c8/a62767a6b374a0dfb02d2a0456e5f56a372cdd1689dbc6ffb6bf1ddedbc0/numpy-1.22.1.zip (11.4MB)
#      |████████████████████████████████| 11.4MB 8.3MB/s eta 0:00:01    |██▎                             | 819kB 4.7MB/s eta 0:00:03     |███▌                            | 1.3MB 4.7MB/s eta 0:00:03     |███████▊                        | 2.7MB 4.7MB/s eta 0:00:02
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: pyarrow, numpy
#   Building wheel for pyarrow (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/tmp6my1ng1f
#        cwd: /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/pyarrow
#   Complete output (220 lines):
#   /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-build-env-dc_rjsez/overlay/lib/python3.8/site-packages/setuptools_scm/integration.py:17: RuntimeWarning:
#   ERROR: setuptools==41.2.0 is used in combination with setuptools_scm>=6.x
#
#   Your build configuration is incomplete and previously worked by accident!
#
#
#   This happens as setuptools is unable to replace itself when a activated build dependency
#   requires a more recent setuptools version
#   (it does not respect "setuptools>X" in setup_requires).
#
#
#   setuptools>=31 is required for setup.cfg metadata support
#   setuptools>=42 is required for pyproject.toml configuration support
#
#   Suggested workarounds if applicable:
#    - preinstalling build dependencies like setuptools_scm before running setup.py
#    - installing setuptools_scm using the system package manager to ensure consistency
#    - migrating from the deprecated setup_requires mechanism to pep517/518
#      and using a pyproject.toml to declare build dependencies
#      which are reliably pre-installed before running the build tools
#
#     warnings.warn(
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.14.6-x86_64-3.8
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/orc.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_generated_version.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/compat.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/benchmark.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/parquet.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_compute_docstrings.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/ipc.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/util.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/flight.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/cffi.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/filesystem.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/plasma.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/types.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/dataset.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/cuda.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/feather.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/pandas_compat.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/fs.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/csv.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/jvm.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/hdfs.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/json.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/serialization.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/compute.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_tensor.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_ipc.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/conftest.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_convert_builtin.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_misc.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_gandiva.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/strategies.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_adhoc_memory_leak.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/arrow_7980.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/util.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_orc.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_table.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_array.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_deprecations.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_serialization_deprecated.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_io.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_util.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_cuda_numba_interop.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_cffi.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_schema.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_jvm.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_plasma_tf_op.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_fs.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_filesystem.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/pandas_threaded_import.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/pandas_examples.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_cython.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_sparse_tensor.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_dataset.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_builder.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_cuda.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_extension_type.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_feather.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_pandas.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_memory.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_flight.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_json.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_serialization.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_compute.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_hdfs.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/deserialize_buffer.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_strategies.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_csv.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_plasma.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_scalars.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_gdb.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/test_types.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   running egg_info
#   writing pyarrow.egg-info/PKG-INFO
#   writing dependency_links to pyarrow.egg-info/dependency_links.txt
#   writing entry points to pyarrow.egg-info/entry_points.txt
#   writing requirements to pyarrow.egg-info/requires.txt
#   writing top-level names to pyarrow.egg-info/top_level.txt
#   listing git files failed - pretending there aren't any
#   reading manifest file 'pyarrow.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '../LICENSE.txt'
#   warning: no files found matching '../NOTICE.txt'
#   warning: no previously-included files matching '*.so' found anywhere in distribution
#   warning: no previously-included files matching '*.pyc' found anywhere in distribution
#   warning: no previously-included files matching '*~' found anywhere in distribution
#   warning: no previously-included files matching '#*' found anywhere in distribution
#   warning: no previously-included files matching '.git*' found anywhere in distribution
#   warning: no previously-included files matching '.DS_Store' found anywhere in distribution
#   no previously-included directories found matching '.asv'
#   writing manifest file 'pyarrow.egg-info/SOURCES.txt'
#   copying pyarrow/__init__.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_compute.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_compute.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_csv.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_csv.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_cuda.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_cuda.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_dataset.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_dataset.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_dataset_orc.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_dataset_parquet.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_feather.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_flight.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_fs.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_fs.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_hdfs.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_hdfsio.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_json.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_orc.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_orc.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_parquet.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_parquet.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_plasma.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/_s3fs.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/array.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/benchmark.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/builder.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/compat.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/config.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/error.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/gandiva.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/io.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/ipc.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/lib.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/lib.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/memory.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/pandas-shim.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/public-api.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/scalar.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/serialization.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/table.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/tensor.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   copying pyarrow/types.pxi -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/__init__.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/common.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libarrow.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libarrow_cuda.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libarrow_dataset.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libarrow_dataset_parquet.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libarrow_feather.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libarrow_flight.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libarrow_fs.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libgandiva.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   copying pyarrow/includes/libplasma.pxd -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/includes
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tensorflow
#   copying pyarrow/tensorflow/plasma_op.cc -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tensorflow
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/vendored
#   copying pyarrow/vendored/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/vendored
#   copying pyarrow/vendored/docscrape.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/vendored
#   copying pyarrow/vendored/version.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/vendored
#   copying pyarrow/tests/bound_function_visit_strings.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   copying pyarrow/tests/pyarrow_cython_example.pyx -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/feather
#   copying pyarrow/tests/data/feather/v0.17.0.version=2-compression=lz4.feather -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/feather
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/README.md -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.emptyFile.jsn.gz -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.emptyFile.orc -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.test1.jsn.gz -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.test1.orc -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.testDate1900.jsn.gz -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/TestOrcFile.testDate1900.orc -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/decimal.jsn.gz -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   copying pyarrow/tests/data/orc/decimal.orc -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/orc
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/parquet
#   copying pyarrow/tests/data/parquet/v0.7.1.all-named-index.parquet -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/parquet
#   copying pyarrow/tests/data/parquet/v0.7.1.column-metadata-handling.parquet -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/parquet
#   copying pyarrow/tests/data/parquet/v0.7.1.parquet -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/parquet
#   copying pyarrow/tests/data/parquet/v0.7.1.some-named-index.parquet -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/data/parquet
#   creating build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/common.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/conftest.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_basic.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_compliant_nested_type.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_data_types.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_dataset.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_datetime.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_metadata.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_pandas.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_parquet_file.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   copying pyarrow/tests/parquet/test_parquet_writer.py -> build/lib.macosx-10.14.6-x86_64-3.8/pyarrow/tests/parquet
#   running build_ext
#   creating /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/pyarrow/build/temp.macosx-10.14.6-x86_64-3.8
#   -- Running cmake for pyarrow
#   cmake -DPYTHON_EXECUTABLE=/Library/Developer/CommandLineTools/usr/bin/python3 -DPython3_EXECUTABLE=/Library/Developer/CommandLineTools/usr/bin/python3  -DPYARROW_BUILD_CUDA=off -DPYARROW_BUILD_FLIGHT=off -DPYARROW_BUILD_GANDIVA=off -DPYARROW_BUILD_DATASET=off -DPYARROW_BUILD_ORC=off -DPYARROW_BUILD_PARQUET=off -DPYARROW_BUILD_PLASMA=off -DPYARROW_BUILD_S3=off -DPYARROW_BUILD_HDFS=off -DPYARROW_USE_TENSORFLOW=off -DPYARROW_BUNDLE_ARROW_CPP=off -DPYARROW_BUNDLE_BOOST=off -DPYARROW_GENERATE_COVERAGE=off -DPYARROW_BOOST_USE_SHARED=on -DPYARROW_PARQUET_USE_SHARED=on -DCMAKE_BUILD_TYPE=release /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/pyarrow
#   unable to execute 'cmake': No such file or directory
#   error: command 'cmake' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pyarrow
#   Running setup.py clean for pyarrow
#   Building wheel for numpy (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/tmplibn2ur2
#        cwd: /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/numpy
#   Complete output (1693 lines):
#   Running from numpy source directory.
#   Cythonizing sources
#   Processing numpy/random/_bounded_integers.pxd.in
#   Processing numpy/random/_philox.pyx
#   Processing numpy/random/_bounded_integers.pyx.in
#   Processing numpy/random/_sfc64.pyx
#   Processing numpy/random/_mt19937.pyx
#   Processing numpy/random/bit_generator.pyx
#   Processing numpy/random/mtrand.pyx
#   Processing numpy/random/_generator.pyx
#   Processing numpy/random/_pcg64.pyx
#   Processing numpy/random/_common.pyx
#   INFO: blas_opt_info:
#   INFO: blas_armpl_info:
#   INFO: customize UnixCCompiler
#   INFO:   libraries armpl_lp64_mp not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blas_mkl_info:
#   INFO:   libraries mkl_rt not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blis_info:
#   INFO:   libraries blis not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_info:
#   INFO:   libraries openblas not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: accelerate_info:
#   INFO:   libraries accelerate not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO: Library accelerate was not found. Ignoring
#   INFO:   libraries veclib not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO: Library veclib was not found. Ignoring
#   INFO:   FOUND:
#   INFO:     extra_compile_args = ['-msse3', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#   INFO:     extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#   INFO:     define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#   INFO:
#   INFO:   FOUND:
#   INFO:     extra_compile_args = ['-msse3', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#   INFO:     extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#   INFO:     define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#   INFO:
#   non-existing path in 'numpy/distutils': 'site.cfg'
#   INFO: lapack_opt_info:
#   INFO: lapack_armpl_info:
#   INFO:   libraries armpl_lp64_mp not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: lapack_mkl_info:
#   INFO:   libraries mkl_rt not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_lapack_info:
#   INFO:   libraries openblas not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_clapack_info:
#   INFO:   libraries openblas,lapack not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: flame_info:
#   INFO:   libraries flame not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO:   FOUND:
#   INFO:     extra_compile_args = ['-msse3', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#   INFO:     extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#   INFO:     define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#   INFO:
#   Warning: attempted relative import with no known parent package
#   /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   INFO: build_src
#   INFO: building py_modules sources
#   creating build
#   creating build/src.macosx-10.14.6-x86_64-3.8
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   INFO: building library "npymath" sources
#   WARN: Could not locate executable gfortran
#   WARN: Could not locate executable f95
#   WARN: Could not locate executable nagfor
#   WARN: Could not locate executable f90
#   WARN: Could not locate executable f77
#   WARN: Could not locate executable xlf90
#   WARN: Could not locate executable xlf
#   WARN: Could not locate executable ifort
#   WARN: Could not locate executable ifc
#   WARN: Could not locate executable g77
#   WARN: Could not locate executable g95
#   WARN: Could not locate executable pgfortran
#   WARN: don't know how to compile Fortran code on platform 'posix'
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath/npy_math_internal.h
#   INFO:   adding 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath' to include_dirs.
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath/ieee754.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath/npy_math_complex.c
#   INFO: None - nothing done with h_files = ['build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath/npy_math_internal.h']
#   INFO: building library "npyrandom" sources
#   INFO: building extension "numpy.core._multiarray_tests" sources
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/_multiarray_tests.c
#   INFO: building extension "numpy.core._multiarray_umath" sources
#   non-existing path in 'numpy/core': 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common'
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/arraytypes.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/einsum.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/einsum_sumprod.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/lowlevel_strided_loops.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/nditer_templ.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/scalartypes.c
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_sort.h
#   INFO:   adding 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common' to include_dirs.
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/quicksort.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/mergesort.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/timsort.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/heapsort.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_partition.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/selection.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_binsearch.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/binsearch.c
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/funcs.inc
#   INFO:   adding 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath' to include_dirs.
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/simd.inc
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_utils.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_unary_fp.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_arithm_fp.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_arithmetic.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_trigonometric.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_umath_fp.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_exponent_log.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/matmul.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/matmul.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/scalarmath.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/templ_common.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_cpu_features.c
#   INFO: numpy.core - nothing done with h_files = ['build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_sort.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_partition.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_binsearch.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/funcs.inc', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/simd.inc', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_utils.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/matmul.h', 'numpy/core/src/umath/clip.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/templ_common.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy/config.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy/__multiarray_api.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy/__ufunc_api.h']
#   INFO: building extension "numpy.core._umath_tests" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/_umath_tests.c
#   INFO: building extension "numpy.core._rational_tests" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/_rational_tests.c
#   INFO: building extension "numpy.core._struct_ufunc_tests" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/_struct_ufunc_tests.c
#   INFO: building extension "numpy.core._operand_flag_tests" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/_operand_flag_tests.c
#   INFO: building extension "numpy.core._simd" sources
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd_inc.h
#   INFO:   adding 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd' to include_dirs.
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd_data.inc
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd.dispatch.c
#   INFO: numpy.core - nothing done with h_files = ['build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd_inc.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd_data.inc']
#   INFO: building extension "numpy.fft._pocketfft_internal" sources
#   INFO: building extension "numpy.linalg.lapack_lite" sources
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/linalg
#   INFO: building extension "numpy.linalg._umath_linalg" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/linalg/umath_linalg.c
#   INFO: building extension "numpy.random._mt19937" sources
#   INFO: building extension "numpy.random._philox" sources
#   INFO: building extension "numpy.random._pcg64" sources
#   INFO: building extension "numpy.random._sfc64" sources
#   INFO: building extension "numpy.random._common" sources
#   INFO: building extension "numpy.random.bit_generator" sources
#   INFO: building extension "numpy.random._generator" sources
#   INFO: building extension "numpy.random._bounded_integers" sources
#   INFO: building extension "numpy.random.mtrand" sources
#   INFO: building data_files sources
#   INFO: build_src: building npy-pkg config files
#   running build_py
#   creating build/lib.macosx-10.14.6-x86_64-3.8
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/conftest.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/version.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/_version.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/_globals.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/dual.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/_distributor_init.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/ctypeslib.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/matlib.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/_pytesttester.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying build/src.macosx-10.14.6-x86_64-3.8/numpy/__config__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_constants.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_elementwise_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_sorting_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_manipulation_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_searching_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_typing.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_utility_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_array_object.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_data_type_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_dtypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/linalg.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_statistical_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_set_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_creation_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_set_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_array_object.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_elementwise_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_sorting_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_creation_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   copying numpy/compat/py3k.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   copying numpy/compat/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   copying numpy/compat/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   copying numpy/compat/_inspect.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat/tests
#   copying numpy/compat/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat/tests
#   copying numpy/compat/tests/test_compat.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/umath.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/fromnumeric.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_dtype.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_add_newdocs.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_methods.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_internal.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_string_helpers.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/multiarray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_asarray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/records.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_add_newdocs_scalars.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_machar.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/setup_common.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/memmap.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/overrides.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/getlimits.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_dtype_ctypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/defchararray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/shape_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/numeric.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/function_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/einsumfunc.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/umath_tests.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_ufunc_config.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_exceptions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/numerictypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_type_aliases.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/cversions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/arrayprint.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/code_generators/generate_numpy_api.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_numerictypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalar_methods.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalarmath.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_item_selection.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_array_coercion.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_machar.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_unicode.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_cpu_dispatcher.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_arrayprint.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalarbuffer.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_indexerrors.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_print.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_half.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_arraymethod.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_mem_overlap.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_shape_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_hashtable.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_deprecations.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_errstate.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_records.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_mem_policy.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_simd.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalarinherit.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_indexing.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_umath.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_numeric.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_function_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_datetime.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test__exceptions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_extint128.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_cython.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_umath_complex.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/_locales.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_custom_dtypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_defchararray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_conversion_utils.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalarprint.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_casting_unittests.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_abc.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_ufunc.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_dtype.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_umath_accuracy.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_simd_module.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_getlimits.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_dlpack.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_einsum.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_api.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_longdouble.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_overrides.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalar_ctors.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_multiarray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_memmap.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_nditer.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_cpu_features.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_protocols.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_argparse.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_regression.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/unixccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/numpy_distribution.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/conv_template.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/cpuinfo.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/ccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
# ...
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/temp_elide.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/typeinfo.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/usertypes.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/binsearch.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/mergesort.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/multiarray/array_coercion.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/array_method.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/umathmodule.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/umath/legacy_array_method.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/timsort.c
#   1 warning generated.
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/reduction.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/umath/ufunc_object.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/extobj.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/scalarmath.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/mapping.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/methods.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/umath/ufunc_type_resolution.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/multiarraymodule.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/umath/override.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/heapsort.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/umath/_scaled_float_dtype.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/array_assign.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/mem_overlap.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/npy_argparse.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/npy_hashtable.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/selection.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/npy_longdouble.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/ucsnarrow.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/ufunc_override.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/numpyos.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_cpu_features.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   numpy/core/src/common/npy_cpu_features.c.src:125:1: warning: unused function 'npy__cpu_baseline_fid' [-Wunused-function]
#   npy__cpu_baseline_fid(const char *feature)
#   ^
#   numpy/core/src/common/npy_cpu_features.c.src:138:1: warning: unused function 'npy__cpu_dispatch_fid' [-Wunused-function]
#   npy__cpu_dispatch_fid(const char *feature)
#   ^
#   3 warnings generated.
#   numpy/core/src/common/npy_cpu_features.c.src:125:1: warning: unused function 'npy__cpu_baseline_fid' [-Wunused-function]
#   npy__cpu_baseline_fid(const char *feature)
#   ^
#   numpy/core/src/common/npy_cpu_features.c.src:138:1: warning: unused function 'npy__cpu_dispatch_fid' [-Wunused-function]
#   npy__cpu_dispatch_fid(const char *feature)
#   ^
#   2 warnings generated.
#   INFO: clang: numpy/core/src/common/cblasfuncs.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/nditer_templ.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/python_xerbla.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/nditer_api.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/matmul.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/dispatching.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   error: Command "clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -ftrapping-math -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNO_ATLAS_INFO=3 -DHAVE_CBLAS -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath -Inumpy/core/include -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/distutils/include -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -Inumpy/core/src/_simd -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/include/python3.8 -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath -c numpy/core/src/multiarray/dragon4.c -o build/temp.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/dragon4.o -MMD -MF build/temp.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/dragon4.o.d -msse3 -I/System/Library/Frameworks/vecLib.framework/Headers" failed with exit status 1
#   INFO:
#   ########### EXT COMPILER OPTIMIZATION ###########
#   INFO: Platform      :
#     Architecture: x64
#     Compiler    : clang
#
#   CPU baseline  :
#     Requested   : 'min'
#     Enabled     : none
#     Flags       : none
#     Extra checks: none
#
#   CPU dispatch  :
#     Requested   : 'max -xop -fma4'
#     Enabled     : none
#     Generated   : none
#   INFO: CCompilerOpt.cache_flush[817] : write cache to path -> /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/numpy/build/temp.macosx-10.14.6-x86_64-3.8/ccompiler_opt_cache_ext.py
#   INFO:
#   ########### CLIB COMPILER OPTIMIZATION ###########
#   INFO: Platform      :
#     Architecture: x64
#     Compiler    : clang
#
#   CPU baseline  :
#     Requested   : 'min'
#     Enabled     : none
#     Flags       : none
#     Extra checks: none
#
#   CPU dispatch  :
#     Requested   : 'max -xop -fma4'
#     Enabled     : none
#     Generated   : none
#   INFO: CCompilerOpt.cache_flush[817] : write cache to path -> /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/numpy/build/temp.macosx-10.14.6-x86_64-3.8/ccompiler_opt_cache_clib.py
#   ----------------------------------------
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/numpy/setup.py'"'"'; __file__='"'"'/private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/numpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/numpy
#   Complete output (10 lines):
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for numpy
# Failed to build pyarrow numpy
# Building wheels for collected packages: python-snappy
#   Building wheel for python-snappy (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/python-snappy/setup.py'"'"'; __file__='"'"'/private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/python-snappy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-wheel-neg8zt_d --python-tag cp38
#        cwd: /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-mq0jcppl/python-snappy/
#   Complete output (25 lines):
#   /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'cffi_modules'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.14.6-x86_64-3.8
#   creating build/lib.macosx-10.14.6-x86_64-3.8/snappy
#   copying snappy/snappy.py -> build/lib.macosx-10.14.6-x86_64-3.8/snappy
#   copying snappy/snappy_cffi.py -> build/lib.macosx-10.14.6-x86_64-3.8/snappy
#   copying snappy/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/snappy
#   copying snappy/hadoop_snappy.py -> build/lib.macosx-10.14.6-x86_64-3.8/snappy
#   copying snappy/snappy_formats.py -> build/lib.macosx-10.14.6-x86_64-3.8/snappy
#   copying snappy/__main__.py -> build/lib.macosx-10.14.6-x86_64-3.8/snappy
#   copying snappy/snappy_cffi_builder.py -> build/lib.macosx-10.14.6-x86_64-3.8/snappy
#   running build_ext
#   building 'snappy._snappy' extension
#   creating build/temp.macosx-10.14.6-x86_64-3.8
#   creating build/temp.macosx-10.14.6-x86_64-3.8/snappy
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/include/python3.8 -c snappy/snappymodule.cc -o build/temp.macosx-10.14.6-x86_64-3.8/snappy/snappymodule.o
#   snappy/snappymodule.cc:32:10: fatal error: 'snappy-c.h' file not found
#   #include <snappy-c.h>
#            ^~~~~~~~~~~~
#   1 error generated.
#   error: command 'clang' failed with exit status 1
#   ----------------------------------------
#   ERROR: Failed building wheel for python-snappy
#   Running setup.py clean for python-snappy
# Failed to build python-snappy
# ERROR: Could not build wheels for pyarrow, numpy which use PEP 517 and cannot be installed directly
# WARNING: You are using pip version 19.2.3, however version 22.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Collecting numpy
#   Using cached https://files.pythonhosted.org/packages/0a/c8/a62767a6b374a0dfb02d2a0456e5f56a372cdd1689dbc6ffb6bf1ddedbc0/numpy-1.22.1.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: numpy
#   Building wheel for numpy (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/tmpemb0eymh
#        cwd: /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-d2iiynf5/numpy
#   Complete output (1543 lines):
#   Running from numpy source directory.
#   Cythonizing sources
#   Processing numpy/random/_bounded_integers.pxd.in
#   Processing numpy/random/_philox.pyx
#   Processing numpy/random/_bounded_integers.pyx.in
#   Processing numpy/random/_sfc64.pyx
#   Processing numpy/random/_mt19937.pyx
#   Processing numpy/random/bit_generator.pyx
#   Processing numpy/random/mtrand.pyx
#   Processing numpy/random/_generator.pyx
#   Processing numpy/random/_pcg64.pyx
#   Processing numpy/random/_common.pyx
#   INFO: blas_opt_info:
#   INFO: blas_armpl_info:
#   INFO: customize UnixCCompiler
#   INFO:   libraries armpl_lp64_mp not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blas_mkl_info:
#   INFO:   libraries mkl_rt not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blis_info:
#   INFO:   libraries blis not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_info:
#   INFO:   libraries openblas not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: accelerate_info:
#   INFO:   libraries accelerate not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO: Library accelerate was not found. Ignoring
#   INFO:   libraries veclib not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO: Library veclib was not found. Ignoring
#   INFO:   FOUND:
#   INFO:     extra_compile_args = ['-msse3', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#   INFO:     extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#   INFO:     define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#   INFO:
#   INFO:   FOUND:
#   INFO:     extra_compile_args = ['-msse3', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#   INFO:     extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#   INFO:     define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#   INFO:
#   non-existing path in 'numpy/distutils': 'site.cfg'
#   INFO: lapack_opt_info:
#   INFO: lapack_armpl_info:
#   INFO:   libraries armpl_lp64_mp not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: lapack_mkl_info:
#   INFO:   libraries mkl_rt not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_lapack_info:
#   INFO:   libraries openblas not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_clapack_info:
#   INFO:   libraries openblas,lapack not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: flame_info:
#   INFO:   libraries flame not found in ['/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib', '/usr/local/lib', '/usr/lib']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO:   FOUND:
#   INFO:     extra_compile_args = ['-msse3', '-I/System/Library/Frameworks/vecLib.framework/Headers']
#   INFO:     extra_link_args = ['-Wl,-framework', '-Wl,Accelerate']
#   INFO:     define_macros = [('NO_ATLAS_INFO', 3), ('HAVE_CBLAS', None)]
#   INFO:
#   Warning: attempted relative import with no known parent package
#   /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/distutils/dist.py:274: UserWarning: Unknown distribution option: 'define_macros'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running config_cc
#   INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   INFO: build_src
#   INFO: building py_modules sources
#   creating build
#   creating build/src.macosx-10.14.6-x86_64-3.8
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   INFO: building library "npymath" sources
#   WARN: Could not locate executable gfortran
#   WARN: Could not locate executable f95
#   WARN: Could not locate executable nagfor
#   WARN: Could not locate executable f90
#   WARN: Could not locate executable f77
#   WARN: Could not locate executable xlf90
#   WARN: Could not locate executable xlf
#   WARN: Could not locate executable ifort
#   WARN: Could not locate executable ifc
#   WARN: Could not locate executable g77
#   WARN: Could not locate executable g95
#   WARN: Could not locate executable pgfortran
#   WARN: don't know how to compile Fortran code on platform 'posix'
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath/npy_math_internal.h
#   INFO:   adding 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath' to include_dirs.
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath/ieee754.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath/npy_math_complex.c
#   INFO: None - nothing done with h_files = ['build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath/npy_math_internal.h']
#   INFO: building library "npyrandom" sources
#   INFO: building extension "numpy.core._multiarray_tests" sources
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/_multiarray_tests.c
#   INFO: building extension "numpy.core._multiarray_umath" sources
#   non-existing path in 'numpy/core': 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common'
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/arraytypes.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/einsum.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/einsum_sumprod.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/lowlevel_strided_loops.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/nditer_templ.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/scalartypes.c
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_sort.h
#   INFO:   adding 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common' to include_dirs.
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/quicksort.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/mergesort.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/timsort.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/heapsort.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_partition.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/selection.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_binsearch.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/binsearch.c
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/funcs.inc
#   INFO:   adding 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath' to include_dirs.
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/simd.inc
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_utils.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_unary_fp.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_arithm_fp.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_arithmetic.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_trigonometric.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_umath_fp.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_exponent_log.dispatch.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/matmul.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/matmul.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/scalarmath.c
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/templ_common.h
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_cpu_features.c
#   INFO: numpy.core - nothing done with h_files = ['build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_sort.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_partition.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_binsearch.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/funcs.inc', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/simd.inc', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops_utils.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/matmul.h', 'numpy/core/src/umath/clip.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/templ_common.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy/config.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy/_numpyconfig.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy/__multiarray_api.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy/__ufunc_api.h']
#   INFO: building extension "numpy.core._umath_tests" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/_umath_tests.c
#   INFO: building extension "numpy.core._rational_tests" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/_rational_tests.c
#   INFO: building extension "numpy.core._struct_ufunc_tests" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/_struct_ufunc_tests.c
#   INFO: building extension "numpy.core._operand_flag_tests" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/_operand_flag_tests.c
#   INFO: building extension "numpy.core._simd" sources
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd_inc.h
#   INFO:   adding 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd' to include_dirs.
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd_data.inc
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd.dispatch.c
#   INFO: numpy.core - nothing done with h_files = ['build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd_inc.h', 'build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/_simd/_simd_data.inc']
#   INFO: building extension "numpy.fft._pocketfft_internal" sources
#   INFO: building extension "numpy.linalg.lapack_lite" sources
#   creating build/src.macosx-10.14.6-x86_64-3.8/numpy/linalg
#   INFO: building extension "numpy.linalg._umath_linalg" sources
#   INFO: conv_template:> build/src.macosx-10.14.6-x86_64-3.8/numpy/linalg/umath_linalg.c
#   INFO: building extension "numpy.random._mt19937" sources
#   INFO: building extension "numpy.random._philox" sources
#   INFO: building extension "numpy.random._pcg64" sources
#   INFO: building extension "numpy.random._sfc64" sources
#   INFO: building extension "numpy.random._common" sources
#   INFO: building extension "numpy.random.bit_generator" sources
#   INFO: building extension "numpy.random._generator" sources
#   INFO: building extension "numpy.random._bounded_integers" sources
#   INFO: building extension "numpy.random.mtrand" sources
#   INFO: building data_files sources
#   INFO: build_src: building npy-pkg config files
#   running build_py
#   creating build/lib.macosx-10.14.6-x86_64-3.8
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/conftest.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/version.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/_version.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/_globals.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/dual.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/_distributor_init.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/ctypeslib.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/matlib.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying numpy/_pytesttester.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   copying build/src.macosx-10.14.6-x86_64-3.8/numpy/__config__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_constants.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_elementwise_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_sorting_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_manipulation_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_searching_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_typing.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_utility_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_array_object.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_data_type_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_dtypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/linalg.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_statistical_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_set_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   copying numpy/array_api/_creation_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_set_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_array_object.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_elementwise_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_sorting_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   copying numpy/array_api/tests/test_creation_functions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/array_api/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   copying numpy/compat/py3k.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   copying numpy/compat/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   copying numpy/compat/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   copying numpy/compat/_inspect.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat/tests
#   copying numpy/compat/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat/tests
#   copying numpy/compat/tests/test_compat.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/compat/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/umath.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/fromnumeric.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_dtype.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_add_newdocs.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_methods.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_internal.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_string_helpers.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/multiarray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_asarray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/records.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_add_newdocs_scalars.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_machar.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/setup_common.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/memmap.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/overrides.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/getlimits.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_dtype_ctypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/defchararray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/shape_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/numeric.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/function_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/einsumfunc.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/umath_tests.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_ufunc_config.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_exceptions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/numerictypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/_type_aliases.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/cversions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/arrayprint.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   copying numpy/core/code_generators/generate_numpy_api.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_numerictypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalar_methods.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalarmath.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_item_selection.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_array_coercion.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_machar.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_unicode.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_cpu_dispatcher.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_arrayprint.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalarbuffer.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_indexerrors.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_print.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_half.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_arraymethod.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_mem_overlap.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_shape_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_hashtable.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_deprecations.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_errstate.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_records.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_mem_policy.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_simd.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalarinherit.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_indexing.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_umath.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_numeric.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_function_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_datetime.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test__exceptions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_extint128.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_cython.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_umath_complex.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/_locales.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_custom_dtypes.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_defchararray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_conversion_utils.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalarprint.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_casting_unittests.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_abc.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_ufunc.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_dtype.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_umath_accuracy.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_simd_module.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_getlimits.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_dlpack.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_einsum.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_api.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_longdouble.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_overrides.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_scalar_ctors.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_multiarray.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_memmap.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_nditer.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_cpu_features.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_protocols.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_argparse.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   copying numpy/core/tests/test_regression.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/core/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/unixccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/numpy_distribution.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/conv_template.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/cpuinfo.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/ccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/msvc9compiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/npy_pkg_config.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/misc_util.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/log.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/line_endings.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/lib2def.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/pathccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/system_info.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/core.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/exec_command.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/from_template.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/mingw32ccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/extension.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/msvccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/armccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/intelccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/_shell_utils.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying numpy/distutils/ccompiler_opt.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   copying build/src.macosx-10.14.6-x86_64-3.8/numpy/distutils/__config__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/build.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/config_compiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/build_ext.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/config.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/install_headers.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/build_py.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/build_src.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/sdist.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/build_scripts.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/bdist_rpm.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/install_clib.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/build_clib.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/autodist.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/egg_info.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/install.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/develop.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   copying numpy/distutils/command/install_data.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/command
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/gnu.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/compaq.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/intel.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/none.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/nag.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/pg.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/ibm.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/sun.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/nv.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/lahey.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/g95.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/arm.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/mips.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/hpux.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/environment.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/pathf95.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/fujitsu.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/absoft.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   copying numpy/distutils/fcompiler/vast.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/fcompiler
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_system_info.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_ccompiler_opt_conf.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_mingw32ccompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_from_template.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_log.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_fcompiler_intel.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_misc_util.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_fcompiler.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_build_ext.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_shell_utils.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_exec_command.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_npy_pkg_config.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_fcompiler_nagfor.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_ccompiler_opt.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   copying numpy/distutils/tests/test_fcompiler_gnu.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/distutils/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/doc
#   copying numpy/doc/constants.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/doc
#   copying numpy/doc/ufuncs.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/doc
#   copying numpy/doc/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/doc
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/cfuncs.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/common_rules.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/crackfortran.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/cb_rules.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/rules.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/f2py2e.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/func2subr.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/__version__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/symbolic.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/diagnose.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/capi_maps.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/f90mod_rules.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/f2py_testing.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/use_rules.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/auxfuncs.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   copying numpy/f2py/__main__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_mixed.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_return_logical.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_assumed_shape.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_common.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_kind.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_array_from_pyobj.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_return_real.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_symbolic.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/util.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_size.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_callback.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_string.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_module_doc.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_quoted_character.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_parameter.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_abstract_interface.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_semicolon_split.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_compile_function.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_block_docstring.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_return_integer.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_return_character.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_return_complex.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_crackfortran.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   copying numpy/f2py/tests/test_regression.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/f2py/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft
#   copying numpy/fft/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft
#   copying numpy/fft/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft
#   copying numpy/fft/helper.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft
#   copying numpy/fft/_pocketfft.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft/tests
#   copying numpy/fft/tests/test_pocketfft.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft/tests
#   copying numpy/fft/tests/test_helper.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft/tests
#   copying numpy/fft/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/fft/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/_iotools.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/mixins.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/nanfunctions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/recfunctions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/histograms.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/scimath.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/_version.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/user_array.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/format.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/twodim_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/index_tricks.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/npyio.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/shape_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/stride_tricks.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/utils.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/arrayterator.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/function_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/arraysetops.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/arraypad.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/type_check.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/polynomial.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/_datasource.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   copying numpy/lib/ufunclike.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_type_check.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_utils.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_financial_expired.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_twodim_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_polynomial.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test__iotools.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_shape_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_ufunclike.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_index_tricks.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_arrayterator.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test__version.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_io.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_arraysetops.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_function_base.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_arraypad.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_mixins.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_packbits.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test__datasource.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_stride_tricks.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_recfunctions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_nanfunctions.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_format.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_histograms.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   copying numpy/lib/tests/test_regression.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/lib/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg
#   copying numpy/linalg/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg
#   copying numpy/linalg/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg
#   copying numpy/linalg/linalg.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg/tests
#   copying numpy/linalg/tests/test_linalg.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg/tests
#   copying numpy/linalg/tests/test_deprecations.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg/tests
#   copying numpy/linalg/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg/tests
#   copying numpy/linalg/tests/test_regression.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/linalg/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   copying numpy/ma/extras.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   copying numpy/ma/testutils.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   copying numpy/ma/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   copying numpy/ma/core.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   copying numpy/ma/bench.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   copying numpy/ma/setup.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   copying numpy/ma/timer_comparison.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   copying numpy/ma/mrecords.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   copying numpy/ma/tests/test_old_ma.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   copying numpy/ma/tests/test_core.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   copying numpy/ma/tests/test_deprecations.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   copying numpy/ma/tests/__init__.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   copying numpy/ma/tests/test_subclassing.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   copying numpy/ma/tests/test_extras.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   copying numpy/ma/tests/test_mrecords.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   copying numpy/ma/tests/test_regression.py -> build/lib.macosx-10.14.6-x86_64-3.8/numpy/ma/tests
#   creating build/lib.macosx-10.14.6-x86_64-3.8/numpy/matrixlib
# ...
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/hashdescr.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/item_selection.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/nditer_pywrap.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/iterators.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/multiarray/number.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/refcount.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/multiarray/legacy_dtype_implementation.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/scalarapi.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/multiarray/sequence.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/shape.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/scalartypes.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/vdot.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/quicksort.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/strfuncs.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/temp_elide.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/typeinfo.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/usertypes.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/binsearch.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/mergesort.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/array_coercion.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/array_method.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/umathmodule.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/reduction.c
#   INFO: clang: numpy/core/src/umath/legacy_array_method.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/timsort.c
#   1 warning generated.
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/ufunc_object.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/loops.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/extobj.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/scalarmath.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/mapping.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/methods.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/umath/ufunc_type_resolution.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/override.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/multiarraymodule.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/umath/_scaled_float_dtype.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/heapsort.c
#   1 warning generated.
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: numpy/core/src/common/array_assign.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/mem_overlap.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/npy_argparse.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/npy_hashtable.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/npy_longdouble.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npysort/selection.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/ucsnarrow.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/ufunc_override.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/numpyos.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common/npy_cpu_features.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   numpy/core/src/common/npy_cpu_features.c.src:125:1: warning: unused function 'npy__cpu_baseline_fid' [-Wunused-function]
#   npy__cpu_baseline_fid(const char *feature)
#   ^
#   numpy/core/src/common/npy_cpu_features.c.src:138:1: warning: unused function 'npy__cpu_dispatch_fid' [-Wunused-function]
#   npy__cpu_dispatch_fid(const char *feature)
#   ^
#   3 warnings generated.
#   numpy/core/src/common/npy_cpu_features.c.src:125:1: warning: unused function 'npy__cpu_baseline_fid' [-Wunused-function]
#   npy__cpu_baseline_fid(const char *feature)
#   ^
#   numpy/core/src/common/npy_cpu_features.c.src:138:1: warning: unused function 'npy__cpu_dispatch_fid' [-Wunused-function]
#   npy__cpu_dispatch_fid(const char *feature)
#   ^
#   2 warnings generated.
#   INFO: clang: numpy/core/src/common/cblasfuncs.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/common/python_xerbla.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/nditer_templ.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: numpy/core/src/multiarray/nditer_api.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   1 warning generated.
#   INFO: clang: build/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath/matmul.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   INFO: clang: numpy/core/src/umath/dispatching.c
#   warning: overriding currently unsupported use of floating point exceptions on this target [-Wunsupported-floating-point-opt]
#   1 warning generated.
#   error: Command "clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.8/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -ftrapping-math -DNPY_INTERNAL_BUILD=1 -DHAVE_NPY_CONFIG_H=1 -D_FILE_OFFSET_BITS=64 -D_LARGEFILE_SOURCE=1 -D_LARGEFILE64_SOURCE=1 -DNO_ATLAS_INFO=3 -DHAVE_CBLAS -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/umath -Inumpy/core/include -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/include/numpy -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/distutils/include -Inumpy/core/src/common -Inumpy/core/src -Inumpy/core -Inumpy/core/src/npymath -Inumpy/core/src/multiarray -Inumpy/core/src/umath -Inumpy/core/src/npysort -Inumpy/core/src/_simd -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/include/python3.8 -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/common -Ibuild/src.macosx-10.14.6-x86_64-3.8/numpy/core/src/npymath -c numpy/core/src/multiarray/dragon4.c -o build/temp.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/dragon4.o -MMD -MF build/temp.macosx-10.14.6-x86_64-3.8/numpy/core/src/multiarray/dragon4.o.d -msse3 -I/System/Library/Frameworks/vecLib.framework/Headers" failed with exit status 1
#   INFO:
#   ########### EXT COMPILER OPTIMIZATION ###########
#   INFO: Platform      :
#     Architecture: x64
#     Compiler    : clang
#
#   CPU baseline  :
#     Requested   : 'min'
#     Enabled     : none
#     Flags       : none
#     Extra checks: none
#
#   CPU dispatch  :
#     Requested   : 'max -xop -fma4'
#     Enabled     : none
#     Generated   : none
#   INFO: CCompilerOpt.cache_flush[817] : write cache to path -> /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-d2iiynf5/numpy/build/temp.macosx-10.14.6-x86_64-3.8/ccompiler_opt_cache_ext.py
#   INFO:
#   ########### CLIB COMPILER OPTIMIZATION ###########
#   INFO: Platform      :
#     Architecture: x64
#     Compiler    : clang
#
#   CPU baseline  :
#     Requested   : 'min'
#     Enabled     : none
#     Flags       : none
#     Extra checks: none
#
#   CPU dispatch  :
#     Requested   : 'max -xop -fma4'
#     Enabled     : none
#     Generated   : none
#   INFO: CCompilerOpt.cache_flush[817] : write cache to path -> /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-d2iiynf5/numpy/build/temp.macosx-10.14.6-x86_64-3.8/ccompiler_opt_cache_clib.py
#   ----------------------------------------
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
#   ERROR: Command errored out with exit status 1:
#    command: /Library/Developer/CommandLineTools/usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-d2iiynf5/numpy/setup.py'"'"'; __file__='"'"'/private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-d2iiynf5/numpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: /private/var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/pip-install-d2iiynf5/numpy
#   Complete output (10 lines):
#   Running from numpy source directory.
#
#   `setup.py clean` is not supported, use one of the following instead:
#
#     - `git clean -xdf` (cleans all files)
#     - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                         files that aren't checked into the git repo)
#
#   Add `--force` to your command to use it anyway if you must (unsupported).
#
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for numpy
# Failed to build numpy
# ERROR: Could not build wheels for numpy which use PEP 517 and cannot be installed directly
# WARNING: You are using pip version 19.2.3, however version 22.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import linear_model
import seaborn as sns
import scipy.stats as st

from IPython.display import set_matplotlib_formats
plt.style.use("seaborn")
# %matplotlib inline
set_matplotlib_formats('svg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/dd/6bc_8ck52pqb88t255094g6m0000gn/T/ipykernel_16995/3615087087.py in <module>
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import statsmodels.formula.api as smf
#       5 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ## Generalized Linear Models (GLMs)
#
# Extension of the linear regression model to additional settings, such as:
#
# -   Binary data (logistic regression)
# -   Count data (Poisson regression)
# -   Variance of predictor should vary with mean of predictor
#     (Gamma regression)

# %% [markdown]
# ### Standard Linear Regression
#
# -   The standard linear regression model can be written $$y_i = x_i^T
#            \theta + \epsilon_i$$
# -   The standard assumption is that $\epsilon_i \stackrel{\text{iid}}{\sim}
#            N(0, \sigma^2)$
# -   Under this assumption, three are three key features of the model:
#     1.  The mean of predictions $\mu_i = E[y_i | x_i]$ depends on the linear
#         predictor $\eta_i {\color{blue} \triangleq} x_i^T \theta$
#     2.  The distribution of predictions is $y_i | x_y \sim N(\mu_i, \sigma^2)$
#     3.  The expected response is equal to linear predictor $\mu_i = \eta_i$

# %% [markdown]
# ### GLM: Links and Families
#
# -   The **generalized linear model** loosens restrictions 2 and 3
# -   The distribution of predictions $y_i | x_i$ can come from the family of
#     exponential dispersion models: $$y_i | x_i \sim f_{EDM}(y_i | x_i, \beta, \phi)
#            = \exp \left(\frac{y \beta -  b(\beta)}{\phi} + c(y; \phi) \right)$$
#     -   $\beta$ is called the **canonical parameter** and depends on the linear
#         predictor $\eta$ # --> changes with x
#     -   $\phi$ is called the **dispersion parameter** --> doesnt change with x
# -   Relaxing assumption 3, we also relate the expected response to the linear
#     prediction via a function $g$ called the **link function**: $$g(\mu_i) = \eta_i$$

# %% [markdown]
# ### GLM: 3 key assumptions
#
# -   Restating assumptions 1-3 for the GLM, we have
#     1.  The mean of predictions $\mu_i = E[y_i | x_i]$ depends on the linear
#         predictor $\eta_i \triangleq x_i^T \theta$
#     2.  The distribution of predictions is $y_i | x_i \sim f_{EDM}(y_i |x_i, \beta,
#                   \phi)$
#     3.  The expected response related to the linear predictor my a monotonic
#         link function $g$: $g(\mu_i) = \eta_i$

# %% [markdown]
# ### Example: Linear Regression Model
#
# -   Recall the pdf of the Normal distribution: $$f(y; \mu, \sigma) =
#            \frac{1}{\sigma \sqrt{2 \pi}} \exp \left(\frac{(y - \mu)^2}{2 \sigma^2} \right)$$
# -   The standard linear regression model is a special of the GLM where
#     -   Link function is $g(\mu) = \mu$ (the identity function)
#     -   The parameter $\phi = \sigma^2$
#     -   The parameter $\beta = \mu$
#     -   $b(\beta) = \beta^2 / 2 = \mu^2 / 2$
#     -   $c(y, \phi) = -1/2 \left[y^2/\sigma^2 + \log(2 \pi \sigma^2) \right]$

# %% [markdown]
# ### Example: Logistic Regression
#
# -   The logistic regression model is also a special case of the GLM
# -   To see it, start with $Y \sim Bernoulli(p)$ (note $E[Y] = \mu = p$)
# -   The pmf for the Bernoulli distribution is: $$f(y; p) = p^y(1-p)^{1-y}$$
# -   The GLM is then specified using
#     $$\begin{aligned}
#            g(\mu) &= \log \left(\frac{\mu}{1-\mu} \right) \\
#            \phi &= 1 \\
#            \beta &= \log \left(\frac{\mu}{1-\mu} \right) \\
#            b(\beta) &= \log(1 + \exp(\beta)) \\
#            c(y, \phi) &= 1/y
#            \end{aligned}$$

# %% [markdown]
# ### Note
#
# -   Most of this math is taken care of for us "behind the scenes"
# -   In practice, when using the GLM framework we do the following:
#     1.  Specify the linear predictor $\eta_i = x_i^T \theta$
#     2.  Choose the family of the regression (either Gaussian for linear
#         regression and Binomial/Bernoulli for logistic regression)
#     3. Optionally choose a suitable link function, though often the default link per family is a good choice

# %% [markdown]
# - The implementation/library will take care of parameter estimation
# -   We cover the math here so that we have a sense of the assumptions we are
#     making when we choose a particular model
# -   This helps us choose the right model

# %% [markdown]
# ## GLM Families
#
# - The GLM framework can handle many use cases:
#     - Continuous, real-valued outputs (linear regresion)
#     - Binary outcomes (logistic regression)
#     - Count data (Poisson regression)
#     - Average severity of event (Gamma regression)
#     - Total severity of all events (Tweedie regression)
# - We've learned about linear and logistic regression already
# - We'll now study the other cases

# %% [markdown]
# ### A working example
#
# -   As we study, we will work on a running example
# -   This example is adapted from a sklearn tutorial [here](https://scikit-learn.org/stable/auto_examples/linear_model/plot_tweedie_regression_insurance_claims.html#sphx-glr-download-auto-examples-linear-model-plot-tweedie-regression-insurance-claims-py) (which came from a
#     paper [here](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3164764))
# -   Data: Data for 678,013 auto insurance policies and associated claims from private auto insurer in France
# -   Features: vehicle age, vehicle power, driver age, bonus malus (extra premium for bad driving history), population density in city where driver lives
# -   Target(s): number of claims, amount of money per claim, total expected claim over life of policy

# %% [markdown]
# ### Data Features
#
# Let's load up the dataset and take a look at the feature space

# %%
df = pd.read_parquet("https://css-materials.s3.amazonaws.com/ML/linear_models_2/insurance_claims_data.parquet")
df.info()
df.head()

# info= how many rows and columns there arer
# claimB= number of claims made by the insurance policy holder
# exposure= insurer's way ttoo keep track of how long will tthey be exposed to this insurance policy. i.e: 0.1= one tenth of a year (units of year)
# area (not used)
# vehicule power
# vehicule brand
# ... other info about the insurance policy holder

# %%
df.describe()

# most of the policy holders dont make any claim
# comparee the main and max
# bonus malus--> pay attention

# %% [markdown]
# **Note:**
#
# - A few columns are derived/computed:
#     - `PurePremium = ClaimAmount/Exposure`: the insurance company's expected total claim per unit of exposure
#     - `Frequency = ClaimNb/Exposure`: the number of claims per unit of exposure (year)
#     - `AvgClaimAmount = ClaimAmount/ClaimNb`: average claim value

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 4))
df[["Exposure"]].plot.hist(ax=ax[0,0])
df[["Exposure"]].plot.box(ax=ax[0,1])
df[["ClaimNb"]].plot.hist(ax=ax[1,0])
sns.ecdfplot(df[["AvgClaimAmount"]].query("AvgClaimAmount > 0"))
fig.tight_layout();

# largest amount of policies are at the beginning and at the end
# boxplot represents the same dat
# bottom left: the vast majority of the insurance policy holders didnt make any claim
# bottom right: most clams are small, but there are some outliers of claims with a value of 2000000

# %% [markdown]
# ### Split data
#
# - We will split the dataset into a training and a testing subset
# - This will allow us to see test the out of sample performance of our model

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, test_size=50000)

# copy dataframe to avoid warnings later
df_train = df_train.copy()
df_test = df_test.copy()  

print(f"Training dataset has {df_train.shape[0]} rows and testing has {df_test.shape[0]}")


# split in training and test subsets= instruct the model that has desirable chararcteristics for prrediction (=accurattely predict some new datta that was not trained on) 
# you want to be able to be able to use a subset of the data that i've alreadh collecteed to evaluate the predictive characteristics of the triain model
# and see how well it does
# use the training to build the parameters of the model (training: majoriity of the data)

# %% [markdown]
# ### Objective
#
# - Our objective with this dataset will be to play role of insurer and model the PurePremium amount based on driver characteristics
# - We have two approaches:
#     1. Model the expected number of claims (Poisson) and averge claim amount (Gamma), then multiply the two estimates together
#     2. Model total claim amount directly using a Tweedie regression

# %% [markdown]
# ## Poisson
#
# - The Poisson distribution is a discrete distribution characterizing the number of occurances of an event ($y$) in a fixed amount of time, given the average or expected number of events ($\mu$)
# - The distribution has one parameter $\mu$ and has pmf: $$f(y;\mu) = \frac{\mu^y e^{-\mu}}{y!} = \exp(y \log \mu - \mu - \log y!)$$

# %% [markdown]
# - This has the form of our exponential family distribution with
# $$\begin{aligned}
# \phi &= 1 \\
# \beta &= \log \mu\\
# b(\beta) &= \exp(\beta) = \mu \\
# c(y, \phi) &= - \log y!
# \end{aligned}$$
# - Because $E[y] = \mu > 0$, we must have a link function that maps from $(-\infty, \infty) \rightarrow (0, \infty)$
# - A natural choice for the link function is the log function $g(\mu) = \log(\mu)$, which implies $E[y_i|x_i] =\mu_i = \exp(x_i^T \theta)$

# %% [markdown]
# ### Poisson PMF
#
# - Let's take a look at the pmf for the Poisson distribution

# %%
def plot_pmf(dist, lb=0, ub=20, ax=None, **kw):
    if ax is None:
        _, ax = plt.subplots()
    x = np.arange(lb, ub)
    ax.plot(x, dist.pmf(x), "*-")
    return ax
    
fig, ax = plt.subplots()
λs = [1, 4, 10]
for λ in λs:
    plot_pmf(st.poisson(λ), ax=ax)
ax.legend([f"λ = {λ}" for λ in λs], loc="upper right") 
ax.set_xlabel("y")
ax.set_ylabel(r"$f_{\lambda}(y)$")
ax.set_title("Poisson distribution")
ax.text(10, 0.15, "E[Y | λ] = Var(Y | λ) = λ");

# %% [markdown]
# ### Poisson Claims
#
# - The GLM where the expected response is Poisson distributed is known as Poisson regression
# - To apply Poisson regression to our claims data, our response variable will be the frequency of claims
# - The model we will use is $$
# \begin{aligned}
# E[y_i | x_i] &= \mu_i = \exp(x_i^T \theta) \text{, with} \\
# x_i &= \begin{bmatrix}1 \\ \text{VehPower}_i \\ \text{VehAge}_i \\ \text{DrivAge}_i \\ \text{BonusMalus}_i \\ \log(\text{Density})_i \end{bmatrix}
# \end{aligned}$$
#
# - We will also weight each observation by its `Exposure` to encourage the model to pay attention to high exposure policies

# %%
for _df in [df_train, df_test]:
    _df["log_Density"] = np.log(_df["Density"])

# %% [markdown]
# ### Fitting frequency model
#
# - We can use either statsmodels or sklearn to fit our Poisson regression
# - We'll start with statsmodels

# %%
freq_mod = smf.glm(
    "Frequency ~ VehPower + VehAge + DrivAge + BonusMalus + log_Density", 
    data=df_train, 
    family=sm.families.Poisson(),
    var_weights=df_train["Exposure"]
)
freq_fit = freq_mod.fit()
freq_fit.summary()

# %% [markdown]
# ### Visualizing results
#
# - To help us make sense of these results, we will use a function from the sklearn tutorial above

# %%
def plot_obs_pred(df, feature, weight, observed, predicted, y_label=None,
                  title=None, ax=None, fill_legend=False):
    """Plot observed and predicted - aggregated per feature level.

    Parameters
    ----------
    df : DataFrame
        input data
    feature: str
        a column name of df for the feature to be plotted
    weight : str
        column name of df with the values of weights or exposure
    observed : str
        a column name of df with the observed target
    predicted : DataFrame
        a dataframe, with the same index as df, with the predicted target
    fill_legend : bool, default=False
        whether to show fill_between legend
    """
    # aggregate observed and predicted variables by feature level
    df_ = df.loc[:, [feature, weight]].copy()
    df_["observed"] = df[observed] * df[weight]
    df_["predicted"] = predicted * df[weight]
    df_ = (
        df_.groupby([feature])[[weight, "observed", "predicted"]]
        .sum()
        .assign(observed=lambda x: x["observed"] / x[weight])
        .assign(predicted=lambda x: x["predicted"] / x[weight])
    )

    ax = df_.loc[:, ["observed", "predicted"]].plot(style=".", ax=ax)
    y_max = df_.loc[:, ["observed", "predicted"]].values.max() * 0.8
    p2 = ax.fill_between(
        df_.index,
        0,
        y_max * df_[weight] / df_[weight].values.max(),
        color="g",
        alpha=0.1,
    )
    if fill_legend:
        ax.legend([p2], ["{} distribution".format(feature)])
    ax.set(
        ylabel=y_label if y_label is not None else None,
        title=title if title is not None else "Train: Observed vs Predicted",
    )

# %%
def plot_model_outcomes(fit, df_train, df_test, observed, weight="Exposure"):
    fig, ax = plt.subplots(ncols=2, nrows=3, figsize=(12, 8))

    plot_obs_pred(
        df=df_train,
        feature="DrivAge",
        weight=weight,
        observed=observed,
        predicted=fit.predict(df_train),
        y_label=observed,
        title="train data",
        ax=ax[0, 0],
    )

    plot_obs_pred(
        df=df_test,
        feature="DrivAge",
        weight=weight,
        observed=observed,
        predicted=fit.predict(df_test),
        y_label=observed,
        title="test data",
        ax=ax[0, 1],
        fill_legend=True
    )

    plot_obs_pred(
        df=df_test,
        feature="VehAge",
        weight=weight,
        observed=observed,
        predicted=fit.predict(df_test),
        y_label=observed,
        title="test data",
        ax=ax[1, 0],
        fill_legend=True
    )

    plot_obs_pred(
        df=df_test,
        feature="BonusMalus",
        weight=weight,
        observed=observed,
        predicted=fit.predict(df_test),
        y_label=observed,
        title="test data",
        ax=ax[1, 1],
        fill_legend=True
    )

    plot_obs_pred(
        df=df_test,
        feature="VehPower",
        weight=weight,
        observed=observed,
        predicted=fit.predict(df_test),
        y_label=observed,
        title="test data",
        ax=ax[2, 0],
        fill_legend=True
    )

    plot_obs_pred(
        df=df_test,
        feature="log_Density",
        weight=weight,
        observed=observed,
        predicted=fit.predict(df_test),
        y_label=observed,
        title="test data",
        ax=ax[2, 1],
        fill_legend=True
    )
    fig.tight_layout();
    return fig
    

plot_model_outcomes(freq_fit, df_train, df_test, observed="Frequency", weight="Exposure");

# %% [markdown]
# Comments:
#
# - Claim frequency is very high for drivers younger than 25 and older than 80
# - As BonusMalus rises, so do claims
# - The relationshp between log(Density) and claim frequency is positive, but our model doesn't capture much of the variation

# %% [markdown]
# ## Gamma
#
# - The Gamma distribution is a continuous distribution with support in $\mathbb{R}^{+}$
# - The distribution has two parameters: $\mu, \nu \in \mathbb{R}^{+}$ and has pdf: $$f_{\Gamma}(y; \mu, \nu) = \frac{1}{\Gamma(\nu)} \left(\frac{\mu}{\mu}\right)^{\nu}y^{\nu-1} e^{-\frac{\nu}{\mu} y}$$
# - With some heroic algebraic manipulation, $f_{\Gamma}$ can be put into the form of $f_{EDM}$ (trust us 😉)
# - Because the suppport of the Gamma distribution is $\mathbb{R}^{+}$, we need a link function that can map from $(-\infty, \infty)$ to $(0, \infty)$
# - The most common link function is again the log link, which implies $E[y_i|x_i] =\mu_i = \exp(x_i^T \theta)$

# %% [markdown]
# ### Visualizing $f_{\Gamma}$

# %%
def plot_pdf(dist, lb=0, ub=20, ax=None, **kw):
    if ax is None:
        _, ax = plt.subplots()
    x = np.linspace(lb, ub, 100)
    ax.plot(x, dist.pdf(x), **kw)
    return ax
    
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,6))
μνs = [(0.5, 1), (1, 1), (2,1), (2.5, 0.5), (2.5, 1), (2.5,3)]
for μ in [0.5, 1, 2]:
    ν = 1  # fixed
    label = f"μ={μ}, ν={ν}"
    plot_pdf(st.gamma(μ, scale=μ/ν), ax=ax[0], label=label)
    
for ν in [0.5, 1, 3]:
    μ = 2.5  # fixed
    label = f"μ={μ}, ν={ν}"
    plot_pdf(st.gamma(μ, scale=μ/ν), ax=ax[1], label=label)

for _ax in ax:
    
    _ax.legend(loc="upper right")
    _ax.set_xlabel("y")
    _ax.set_ylabel(r"$f_{\Gamma}(y)$")

ax[0].set_title("Gamma distribution (ν = 1)")
ax[1].set_title("Gamma distribution (μ = 2.5)")
ax[0].text(5, 0.2, "E[y|μ,ν] = μ, Var(y|μ,ν)= μ^2/ν")
fig.tight_layout();

# %% [markdown]
# Comments
#
# - The parameter $\mu$ dictates shape: notice $\mu \le 1$ vs $\mu > 1$
# - $\mu$ has stronger impact on spread of distribution ($\text{Var} = \mu^2/\nu$)

# %% [markdown]
# ### Gamma regression
#
# - The GLM where the expected response is Gamma distributed is called Gamma regression
# - As noted above, the expected value of the model prediction is $E[y_i | x_i] = \mu_i = \exp(x_i^T \theta)$
# - The variance of the prediciton is $\text{Var}(y_i | x_i) = \mu_i^2 / \nu$
# - Note that the variance now changes with the mean
# - This means that Gamma regression is appropriate when the variation in the prediction should increase with the mean value of the prediction

# %% [markdown]
# ### Gamma claims
#
# - We will use Gamma regression to model the average claim amount
# - The implication of the variance depending on the mean makes sense in this setting
#     - Suppose $y_i$ = \$100$. This would come from minor accident. Variance of claim amount for minor damage is small
#
#     - Alternatively, suppose $y_i = \$10,000$. This would be a larger accident. Large accidents likely have higher variance/dispersion
# - We will use the same set of regressors as with the Poisson model

# %%
# note: support of gamma is (0, ∞), not [0, ∞)
# we need to filter out zero claims
df_train_pos = df_train.query("ClaimAmount > 0")
df_test_pos = df_test.query("ClaimAmount > 0")

sev_mod = smf.glm(
    "AvgClaimAmount ~ VehPower + VehAge + DrivAge + BonusMalus + log_Density", 
    data=df_train_pos,
    family=sm.families.Gamma(link=sm.families.links.log()), 
    var_weights=df_train_pos["ClaimNb"]
)
sev_fit = sev_mod.fit()
sev_fit.summary()

# %%
plot_model_outcomes(sev_fit, df_train_pos, df_test_pos, observed="AvgClaimAmount", weight="ClaimNb");

# %% [markdown]
# ## Combining Poisson + Gamma
#
# - We now have models for :
#     - `Frequency ~  Poisson` (Frequency = ClaimNb/Exposure)
#     - `AvgClaimAmount ~  Gamma` (AvgClaimAmount = ClaimAmount/ClaimNb)
# - Our goal is to predict `PurePremium = ClaimAmount/Exposure`
# - We can multiply the prediction from the two models to approximate the PurePremium

# %%
class FreqAvgProduct:
    def __init__(self, freq_fit, sev_fit):
        self.freq_fit = freq_fit
        self.sev_fit = sev_fit
    
    def predict(self, X):
        return self.freq_fit.predict(X) * self.sev_fit.predict(X)

# %%
product_fit = FreqAvgProduct(freq_fit, sev_fit)

# %%
plot_model_outcomes(product_fit, df_train, df_test, observed="PurePremium", weight="Exposure");

# %% [markdown]
# ## Tweedie
#
# - The final GLM we will consider today is called the Tweedie GLM
# - We won't cover the details of the Tweedie distribution here
# - Instead, we'll note that when the Tweedie parameter $p$ is between 1 and 2, the Tweedie GLM acts like the compound Poisson Gamma model we just computed (compound model is special case of Tweedie GLM)
# - We'll use a value of $p = 1.9$ and have statsmodels fit a Tweedie GLM to target the `PurePremium` directly

# %%
pure_mod = smf.glm(
    "PurePremium ~ VehPower + VehAge + DrivAge + BonusMalus + log_Density", 
    data=df_train,
    family=sm.families.Tweedie(link=sm.families.links.log(), var_power=1.9), 
    var_weights=df_train["Exposure"]
)
pure_fit = pure_mod.fit()
pure_fit.summary()

# %%
plot_model_outcomes(pure_fit, df_train, df_test, observed="PurePremium", weight="Exposure");

# %% [markdown]
# ### Ordered Lorenz Curve
#
# - We'll wrap up our analysis by comparing the two models for `PurePremium` against an oracle that can see the future
# - We'll construct a plot of cumulative claims where...
#     - Policy holders are ranked from safest to riskiest (order by `PurePremium`) and laid out on x-axis
#     - Fraction of observed total claims plotted on y-axis
# - This follows the sklearn tutorial and is best understood by seeing it, so let's dive in!

# %%
from sklearn.metrics import auc

def lorenz_curve(y_true, y_pred, exposure):
    y_true, y_pred = np.asarray(y_true), np.asarray(y_pred)
    exposure = np.asarray(exposure)

    # order samples by increasing predicted risk:
    ranking = np.argsort(y_pred)
    ranked_exposure = exposure[ranking]
    ranked_pure_premium = y_true[ranking]
    cumulated_claim_amount = np.cumsum(ranked_pure_premium * ranked_exposure)
    cumulated_claim_amount /= cumulated_claim_amount[-1]
    cumulated_samples = np.linspace(0, 1, len(cumulated_claim_amount))
    return cumulated_samples, cumulated_claim_amount


fig, ax = plt.subplots(figsize=(8, 8))

y_pred_product = freq_fit.predict(df_test) * sev_fit.predict(df_test)
y_pred_total = pure_fit.predict(df_test)

for label, y_pred in [("Frequency * Severity model", y_pred_product),
                      ("Compound Poisson Gamma", y_pred_total)]:
    ordered_samples, cum_claims = lorenz_curve(
        df_test["PurePremium"], y_pred, df_test["Exposure"])
    gini = 1 - 2 * auc(ordered_samples, cum_claims)
    label += " (Gini index: {:.3f})".format(gini)
    ax.plot(ordered_samples, cum_claims, linestyle="-", label=label)

# Oracle model: y_pred == y_test
ordered_samples, cum_claims = lorenz_curve(
    df_test["PurePremium"], df_test["PurePremium"], df_test["Exposure"])
gini = 1 - 2 * auc(ordered_samples, cum_claims)
label = "Oracle (Gini index: {:.3f})".format(gini)
ax.plot(ordered_samples, cum_claims, linestyle="-.", color="gray",
        label=label)

# Random baseline
ax.plot([0, 1], [0, 1], linestyle="--", color="black",
        label="Random baseline")
ax.set(
    title="Lorenz Curves",
    xlabel=('Fraction of policyholders\n'
            '(ordered by model from safest to riskiest)'),
    ylabel='Fraction of total claim amount'
)
ax.legend(loc="upper left")

# %% [markdown]
# ## Summary
#
# - The generalized linear model extends the linear regression framework to settings beyond the case of normally distributed responses with constant variance
# - The GLM is composed of
#     1. A linear prediction $\eta_i =x_i^T \theta$
#     2. A family $y_i | x_i \sim f$
#     3. A link function $g(\mu_i) = \eta_i$
# - The table below summarizes the subtypes of GLM we have learned about:
#
# | Response type | Family | Link |
# | ------------- | ------ | ---- |
# | continuous | gaussian | identity |
# | binary | binomial/bernoulli | logit |
# | count | poisson | log |
# | average severity | gamma | log |
# | total severity | tweedie | log |
